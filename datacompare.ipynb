# %%
import pandas as pd
import numpy as np
import requests
import json
import os
import pprint
# from statesjson import us_states_json
# from states import us_states
from citipy import citipy

# %%
DSD = pd.read_csv("Dark_Sky_Data.csv")

# %%
DSD
# Out:
#                           Country  Limiting Magnitude        Date  Latitude  \
# 0         United States - Alabama                   7  2009-03-22   33.0428
# 1          United States - Alaska                   7  2008-03-05   33.0428
# 2         United States - Arizona                   7  2015-06-13   33.0428
# 3        United States - Arkansas                   7  2007-03-22   33.0428
# 4      United States - California                   7  2014-02-24   33.0428
# ...                           ...                 ...         ...       ...
# 82492     United States - Arizona               -9999  2016-09-12   32.3279
# 82493     United States - Arizona               -9999  2016-09-12   33.3679
# 82494     United States - Arizona               -9999  2015-02-12   32.2337
# 82495     United States - Arizona               -9999  2015-03-17   33.2917
# 82496     United States - Arizona               -9999  2015-03-18   32.1928
#
#        Longitude
# 0        -87.394
# 1        -87.394
# ...

# %%
PC = pd.read_csv("Park Coordinates.csv")
pcrounded = PC.round({"Latitude": 4, "Longitude": 3})
#round to make sure data matches between two DFs

# %%
pcrounded
# Out:
#     Latitude  Longitude                                         Park
# 0    44.3386    -68.273                         Acadia National Park
# 1   -14.2583   -170.683              National Park of American Samoa
# 2    38.7331   -109.593                         Arches National Park
# 3    43.8554   -102.340                       Badlands National Park
# 4    29.1275   -103.243                       Big Bend National Park
# ..       ...        ...                                          ...
# 57   43.6046   -103.421                      Wind Cave National Park
# 58   61.7104   -142.986  Wrangell-St. Elias National Park & Preserve
# 59   44.4280   -110.588                    Yellowstone National Park
# 60   37.8651   -119.538                       Yosemite National Park
# 61   37.2982   -113.026                           Zion National Park
#
# [62 rows x 3 columns]

# %%
def cartesian_product_basic(left, right):
    return (
       DSD.assign(key=1).merge(pcrounded.assign(key=1), on='key').drop('key', 1))
dsd_merged_df = cartesian_product_basic(DSD, pcrounded)
#Credit: Umair Khakoo

# %%
#dsd_df = dsd_merged_df[
   # (abs(dsd_merged_df["Latitude_x"] - dsd_merged_df["Latitude_y"]) <= 0.44) & (abs(dsd_merged_df["Longitude_x"] - dsd_merged_df["Longitude_y"]) <= 0.44)
]

# %%
bool_list = []
for idx, row in dsd_merged_df.iterrows():
    if abs(row["Latitude_x"] - row["Latitude_y"]) <= 0.44 and abs((row["Longitude_x"]) - (row["Longitude_y"])) <= 0.44:
        bool_list.append("True")
    else:
        bool_list.append("False")

# %%
bool_df = pd.DataFrame(bool_list)

# %%
finaldsd_df = dsd_merged_df.merge(bool_df, left_index = True, right_index = True)

# %%
finaldsd_df
# Out:
#                          Country  Limiting Magnitude        Date  Latitude_x  \
# 0        United States - Alabama                   7  2009-03-22     33.0428
# 1        United States - Alabama                   7  2009-03-22     33.0428
# 2        United States - Alabama                   7  2009-03-22     33.0428
# 3        United States - Alabama                   7  2009-03-22     33.0428
# 4        United States - Alabama                   7  2009-03-22     33.0428
# ...                          ...                 ...         ...         ...
# 5114809  United States - Arizona               -9999  2015-03-18     32.1928
# 5114810  United States - Arizona               -9999  2015-03-18     32.1928
# 5114811  United States - Arizona               -9999  2015-03-18     32.1928
# 5114812  United States - Arizona               -9999  2015-03-18     32.1928
# 5114813  United States - Arizona               -9999  2015-03-18     32.1928
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-a930c4ff8da6> in <module>
# ----> 1 finaldsd_df.setindex[0]
#
# ~\.virtualenvs\WeatherPy-HhxaVGdu\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'setindex'
