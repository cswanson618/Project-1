# %%
import pandas as pd
import numpy as np
import requests
import json
import os
import pprint
from statesjson import us_states_json
from states import us_states
from citipy import citipy

# %%
DSD = pd.read_csv("Dark_Sky_Data.csv")

# %%
DSD
# Out:
#                           Country  Limiting Magnitude        Date  Latitude  \
# 0         United States - Alabama                   7  2009-03-22   33.0428
# 1          United States - Alaska                   7  2008-03-05   33.0428
# 2         United States - Arizona                   7  2015-06-13   33.0428
# 3        United States - Arkansas                   7  2007-03-22   33.0428
# 4      United States - California                   7  2014-02-24   33.0428
# ...                           ...                 ...         ...       ...
# 82492     United States - Arizona               -9999  2016-09-12   32.3279
# 82493     United States - Arizona               -9999  2016-09-12   33.3679
# 82494     United States - Arizona               -9999  2015-02-12   32.2337
# 82495     United States - Arizona               -9999  2015-03-17   33.2917
# 82496     United States - Arizona               -9999  2015-03-18   32.1928
#
#        Longitude
# 0        -87.394
# 1        -87.394
# 2        -87.394
# 3        -87.394
# 4        -87.394
# ...          ...
# 82492   -110.932
# 82493   -111.904
# 82494   -110.876
# 82495   -111.977
# 82496   -110.839
#
# [82497 rows x 5 columns]

# %%
PC = pd.read_csv("Park Coordinates.csv")
pcrounded = PC.round({"Latitude": 4, "Longitude": 3})
#round to make sure data matches between two DFs

# %%
pcrounded
# Out:
#     Latitude  Longitude                                         Park
# 0    44.3386    -68.273                         Acadia National Park
# 1   -14.2583   -170.683              National Park of American Samoa
# 2    38.7331   -109.593                         Arches National Park
# 3    43.8554   -102.340                       Badlands National Park
# 4    29.1275   -103.243                       Big Bend National Park
# ..       ...        ...                                          ...
# 57   43.6046   -103.421                      Wind Cave National Park
# 58   61.7104   -142.986  Wrangell-St. Elias National Park & Preserve
# 59   44.4280   -110.588                    Yellowstone National Park
# 60   37.8651   -119.538                       Yosemite National Park
# 61   37.2982   -113.026                           Zion National Park
#
# [62 rows x 3 columns]

# %%
def cartesian_product_basic(left, right):
    return (
       DSD.assign(key=1).merge(pcrounded.assign(key=1), on='key').drop('key', 1))
dsd_merged_df = cartesian_product_basic(DSD, pcrounded)
#Credit: Umair Khakoo

# %%
z = 0
list_lat = []
for row in dsd_merged_df.iterrows():
    lat = abs((dsd_merged_df["Latitude_x"]) - (dsd_merged_df["Latitude_y"]))
    #abs((dsd_merged_df["Longitude_x"]) - (dsd_merged_df["Longitude_y"]))
    list_lat.append(lat)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-27-a79df7b0f41e> in <module>
#       2 list_lat = []
#       3 for row in dsd_merged_df.iterrows():
# ----> 4     lat = abs((dsd_merged_df["Latitude_x"]) - (dsd_merged_df["Latitude_y"]))
#       5     #abs((dsd_merged_df["Longitude_x"]) - (dsd_merged_df["Longitude_y"]))
#       6     list_lat.append(lat)
#
# ~\.virtualenvs\WeatherPy-HhxaVGdu\lib\site-packages\pandas\core\generic.py in __abs__(self)
#    1584
#    1585     def __abs__(self):
# -> 1586         return self.abs()
#    1587
#    1588     def __round__(self, decimals=0):
#
# ~\.virtualenvs\WeatherPy-HhxaVGdu\lib\site-packages\pandas\core\generic.py in abs(self)
#    9940         3    7   40  -50
#    9941         """
# -> 9942         return np.abs(self)
#    9943
#    9944     def describe(self, percentiles=None, include=None, exclude=None):
#
# ~\.virtualenvs\WeatherPy-HhxaVGdu\lib\site-packages\pandas\core\series.py in __array_ufunc__(self, ufunc, method, *inputs, **kwargs)
#     854
#     855         inputs = tuple(extract_array(x, extract_numpy=True) for x in inputs)
# --> 856         result = getattr(ufunc, method)(*inputs, **kwargs)
#     857         if len(set(names)) == 1:
#     858             # we require names to be hashable, right?
#
# MemoryError: Unable to allocate 39.0 MiB for an array with shape (5114814,) and data type float64
